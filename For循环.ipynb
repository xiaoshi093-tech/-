# %%
#利用for循环，打印所有魔术师名单
magicians =['alice','haodong','carolina']
for magician in magicians:
    print(magician)
# Out:
# alice
# haodong
# carolina

# %%
names=['alice','haodong','carolina']
for name in names:
    print(f"{name.title()},你好!欢迎来到python的世界!")
    print(f"我迫不及待想看到你的下一个魔术，{name.title()}!\n")
print("谢谢大家的观看！")
# Out:
# Alice,你好!欢迎来到python的世界!
# 我迫不及待想看到你的下一个魔术，Alice!
#
# Haodong,你好!欢迎来到python的世界!
# 我迫不及待想看到你的下一个魔术，Haodong!
#
# Carolina,你好!欢迎来到python的世界!
# 我迫不及待想看到你的下一个魔术，Carolina!
#
# 谢谢大家的观看！

# %%
animals=['dog','cat','panda','hellokitty']
for animal in animals:
    print(f"A {animal.title()} would make a good pet")
print("\nAny of these animals would make a good pet!")
# Out:
# A Dog would make a good pet
# A Cat would make a good pet
# A Panda would make a good pet
# A Hellokitty would make a good pet
#
# Any of these animals would make a good pet!
